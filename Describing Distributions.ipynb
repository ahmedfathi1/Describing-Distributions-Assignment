# %%
#Importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/medical_dataset.csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
#Analyzing VitD_levels
feature = df['VitD_levels']
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax, kde=True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title('Vitamin D Levels')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt
# Out:
# 3.013147515833447

# %% [markdown]
# ### Answer the following questions:
# - Is it Discrete or Continuous?
#         Continuous
# - Does it have a skew? If so, which direction (+/-)
#       It does not have skew because the mean and median are centrally located
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#         Mesokurtic because kurt ~ 3 above

# %%
#Analyzing Doc_visits
feature = df['Doc_visits']
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax, kde=True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title('Number of Doc_visits')
ax.legend();

# %%
kurt2 = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt2
# Out:
# 2.9919958083381206

# %% [markdown]
# ### Answer the following questions:
# - Is it Discrete or Continuous?
#         Discrete
# - Does it have a skew? If so, which direction (+/-)
#         No skew
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#         Platykurtic because kurt < 3 above

# %%
#Analyzing TotalCharge
feature = df['TotalCharge']
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax, kde=True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title('Total Charge')
ax.legend();

# %%
kurt3 = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt3
# Out:
# 3.2650077463439384

# %% [markdown]
# ### Answer the following questions:
# - Is it Discrete or Continuous?
#         Discrete
# - Does it have a skew? If so, which direction (+/-)
#       Yes, it has a positive skew because most of the values are on the right side, and the median is smaller than the mean
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#         Leptokurtic because kurt > 3 above
